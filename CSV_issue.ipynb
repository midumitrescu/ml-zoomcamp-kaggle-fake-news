# %%
import pandas as pd
df_1 = pd.read_csv(
    "test (1).csv",
    sep=";",
    quotechar='"',
    escapechar="\\",
    engine="python"
)

df_2 = pd.read_csv(
    "train (2).csv",
    sep=";",
    quotechar='"',
    escapechar="\\",
    engine="python")

df_3 = pd.read_csv(
    "evaluation.csv",
    sep=";",
    quotechar='"',
    escapechar="\\",
    engine="python")

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# title         0
# text          0
# label         0
# dtype: int64

# %%
df_2.isna().sum()
# Out:
# Unnamed: 0    0
# title         0
# text          0
# label         0
# dtype: int64

# %%
df_3.isna().sum()
# Out:
# Unnamed: 0    0
# title         0
# text          0
# label         0
# dtype: int64

# %%
df_2_old = pd.read_csv(
    "train (2).csv",
    sep=";")

df_2_old.isna().sum()
# Out:
# Unnamed: 0    0
# title         0
# text          0
# label         0
# dtype: int64

# %%
df_train = pd.read_csv("train (2).csv", engine="python", on_bad_lines="skip", sep=";", quoting=3)
df_test = pd.read_csv("test (1).csv", engine="python", on_bad_lines="skip", sep=";", quoting=3)
df_evaluate = pd.read_csv("evaluation.csv", engine="python", on_bad_lines="skip", sep=";", quoting=3)

# %%
df_test.isna().sum()
# Out:
# Unnamed: 0       0
# title         2802
# text          3061
# label         3320
# dtype: int64
